# %% [markdown]
# # Load Necessary Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.model_selection import  cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
data=pd.read_csv("Breast_cancer.csv")
data.head()
# Out:
#    Class  age  menopause  tumor-size  inv-nodes  node-caps  deg-malig  breast  \
# 0      0    5          1           1          1          2          1       3
# 1      0    5          4           4          5          7         10       3
# 2      0    3          1           1          1          2          2       3
# 3      0    6          8           8          1          3          4       3
# 4      0    4          1           1          3          2          1       3
#
#    breast-quad  irradiat
# 0            1         1
# 1            2         1
# 2            1         1
# 3            7         1
# 4            1         1

# %%
data.columns
# Out:
# Index(['Class', 'age', 'menopause', 'tumor-size', 'inv-nodes', 'node-caps',
#        'deg-malig', 'breast', 'breast-quad', 'irradiat'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 683 entries, 0 to 682
# Data columns (total 10 columns):
# Class          683 non-null int64
# age            683 non-null int64
# menopause      683 non-null int64
# tumor-size     683 non-null int64
# inv-nodes      683 non-null int64
# node-caps      683 non-null int64
# deg-malig      683 non-null int64
# breast         683 non-null int64
# breast-quad    683 non-null int64
# irradiat       683 non-null int64
# dtypes: int64(10)
# memory usage: 53.5 KB

# %%
data.describe()
# Out:
#             Class         age   menopause  tumor-size   inv-nodes   node-caps  \
# count  683.000000  683.000000  683.000000  683.000000  683.000000  683.000000
# mean     0.349927    4.442167    3.150805    3.215227    2.830161    3.234261
# std      0.477296    2.820761    3.065145    2.988581    2.864562    2.223085
# min      0.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      0.000000    2.000000    1.000000    1.000000    1.000000    2.000000
# 50%      0.000000    4.000000    1.000000    1.000000    1.000000    2.000000
# 75%      1.000000    6.000000    5.000000    5.000000    4.000000    4.000000
# max      1.000000   10.000000   10.000000   10.000000   10.000000   10.000000
#
#         deg-malig      breast  breast-quad    irradiat
# count  683.000000  683.000000   683.000000  683.000000
# mean     3.544656    3.445095     2.869693    1.603221
# std      3.643857    2.449697     3.052666    1.732674
# ...

# %%
data.isnull().sum()
# Out:
# Class          0
# age            0
# menopause      0
# tumor-size     0
# inv-nodes      0
# node-caps      0
# deg-malig      0
# breast         0
# breast-quad    0
# irradiat       0
# dtype: int64

# %% [markdown]
# # data visualization

# %%
sns.boxenplot(y="age",x="Class",hue="Class",data=data)

# %%
for i in data.columns:
    plt.figsize=(12,10)
    plt.hist(data[i])
    plt.title(i)
    plt.show()

# %%
sns.countplot(data=data ,x="age",hue="Class")
plt.title("Age Womans have Breast cancer or not")
# Out:
# Text(0.5, 1.0, 'Age Womans have Breast cancer or not')

# %%
sns.pairplot(data=data,hue="Class")
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\user\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# C:\Users\user\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\user\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %% [markdown]
# # Feature Selection

# %%
corr_matrix=data.corr()
corr_matrix
# Out:
#                 Class       age  menopause  tumor-size  inv-nodes  node-caps  \
# Class        1.000000  0.714790   0.820801    0.821891   0.706294   0.690958
# age          0.714790  1.000000   0.642481    0.653470   0.487829   0.523596
# menopause    0.820801  0.642481   1.000000    0.907228   0.706977   0.753544
# tumor-size   0.821891  0.653470   0.907228    1.000000   0.685948   0.722462
# inv-nodes    0.706294  0.487829   0.706977    0.685948   1.000000   0.594548
# node-caps    0.690958  0.523596   0.753544    0.722462   0.594548   1.000000
# deg-malig    0.822696  0.593091   0.691709    0.713878   0.670648   0.585716
# breast       0.758228  0.553742   0.755559    0.735344   0.668567   0.618128
# breast-quad  0.718677  0.534066   0.719346    0.717963   0.603121   0.628926
# irradiat     0.423448  0.350957   0.460755    0.441258   0.418898   0.480583
#
#              deg-malig    breast  breast-quad  irradiat
# Class         0.822696  0.758228     0.718677  0.423448
# ...

# %%
import seaborn as sns
#get correlations of each features in dataset
corr_matrix = data.corr()
top_corr_features = corr_matrix.index
plt.figure(figsize=(8,6))
#plot heat map
g=sns.heatmap(data[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
X=np.array(data.drop(["Class","irradiat"],axis=1))
y=np.array(data.Class)
x_train, x_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=0)

# %% [markdown]
# # Build model use Support Vector Machine Classifier

# %%
# use GridSearchCV to select best Random Forest Classifier 
svc_clf=SVC()
param_grid = { 
    'C': [5,10,15,20,25], 
    'kernel': ['rbf', 'poly', 'sigmoid']
    
}

CV_svc = GridSearchCV(estimator=svc_clf, param_grid=param_grid, cv= 10)
CV_svc.fit(X,y)
print(CV_svc.best_params_)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# ...

# %%
from sklearn.svm import SVC
svc_clf=pip=Pipeline([("Scaler",StandardScaler()),("svc_clf",SVC(C=5,kernel='rbf',probability=True))])
svc_clf.fit(x_train,y_train)
pred=svc_clf.predict(x_test)
print("Accuracy for Support Vector Machine on  data: ",accuracy_score(y_test,pred))
# Out:
# Accuracy for Support Vector Machine on  data:  0.9708029197080292

# %% [markdown]
# # Model Evaluation Metrics

# %%
#import classification_report
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97        87
#            1       0.94      0.96      0.95        50
#
#     accuracy                           0.96       137
#    macro avg       0.96      0.96      0.96       137
# weighted avg       0.96      0.96      0.96       137

# %%
from sklearn.metrics import roc_curve
y_pred_proba = svc_clf.predict_proba(x_test)[:,1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr, label='SVC(auc = %0.3f)' % auc_svc_clf)
plt.xlabel('Fpr')
plt.xlabel('Fpr')
plt.title('SVC(C=5) ROC curve')
plt.legend()
plt.show()
